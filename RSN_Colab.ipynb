# %%
# Download images from GitLab
# Copy pics link from GitLab
# !wget https://gitlab.umiacs.umd.edu/vishnuds/cmsc421/-/raw/main/pics.zip

# Unzip images
# Images are in Files/content/pics
# !unzip pics.zip

# Run yoloV5 from pytorch for the images

# Install yolov5 
# !pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt  # install dependencies

# Import pyTorch
import torch

# Import glob package
import glob

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images
imgs = glob.glob('pics/*.jpeg')  # batch of images
# Inference
results = model(imgs)
print(dir(results))

# Results
results.print()
results.save()  # or .show()


results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 1  433.50  433.50   517.5  714.5    0.687988     27     tiey
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# --2022-10-27 02:56:30--  https://gitlab.umiacs.umd.edu/vishnuds/cmsc421/-/raw/main/pics.zip
# Resolving gitlab.umiacs.umd.edu (gitlab.umiacs.umd.edu)... 128.8.120.131
# Connecting to gitlab.umiacs.umd.edu (gitlab.umiacs.umd.edu)|128.8.120.131|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1627662 (1.6M) [application/octet-stream]
# Saving to: ‘pics.zip.13’
#
# pics.zip.13         100%[===================>]   1.55M  5.09MB/s    in 0.3s
#
# 2022-10-27 02:56:31 (5.09 MB/s) - ‘pics.zip.13’ saved [1627662/1627662]
#
# Archive:  pics.zip
# replace pics/spots_pics.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: pics/spots_pics.yaml
#   inflating: pics/rgb_15.jpeg
#   inflating: pics/rgb_14.jpeg
#   inflating: pics/rgb_13.jpeg
#   inflating: pics/rgb_12.jpeg
#   inflating: pics/rgb_11.jpeg
#   inflating: pics/rgb_10.jpeg
#   inflating: pics/rgb_9.jpeg
#   inflating: pics/rgb_8.jpeg
#   inflating: pics/rgb_7.jpeg
#   inflating: pics/rgb_6.jpeg
#   inflating: pics/rgb_5.jpeg
#   inflating: pics/rgb_4.jpeg
#   inflating: pics/rgb_3.jpeg
#   inflating: pics/rgb_2.jpeg
#   inflating: pics/rgb_1.jpeg
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# INFO:yolov5:YOLOv5 🚀 2022-10-27 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# YOLOv5 🚀 2022-10-27 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# INFO:yolov5:Fusing layers...
# Fusing layers...
# INFO:yolov5:YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# INFO:yolov5:Adding AutoShape...
# Adding AutoShape...
# INFO:yolov5:image 1/15: 720x1280 1 person, 1 chair
# image 2/15: 720x1280 (no detections)
# image 3/15: 720x1280 7 chairs, 1 tv
# image 4/15: 720x1280 2 persons
# image 5/15: 720x1280 1 person
# image 6/15: 720x1280 1 person, 4 chairs
# image 7/15: 720x1280 1 cup, 1 chair, 3 tvs
# image 8/15: 720x1280 1 person, 3 suitcases, 1 skateboard, 1 chair, 6 tvs
# image 9/15: 720x1280 2 persons, 3 chairs, 1 potted plant, 4 tvs
# image 10/15: 720x1280 (no detections)
# image 11/15: 720x1280 2 chairs
# image 12/15: 720x1280 1 suitcase, 2 chairs, 5 tvs, 1 laptop
# image 13/15: 720x1280 1 bench
# image 14/15: 720x1280 2 persons, 6 chairs, 5 tvs
# image 15/15: 720x1280 1 person, 1 backpack, 5 chairs, 4 tvs, 1 laptop
# Speed: 47.0ms pre-process, 259.8ms inference, 1.1ms NMS per image at shape (15, 3, 384, 640)
# image 1/15: 720x1280 1 person, 1 chair
# image 2/15: 720x1280 (no detections)
# image 3/15: 720x1280 7 chairs, 1 tv
# image 4/15: 720x1280 2 persons
# image 5/15: 720x1280 1 person
# image 6/15: 720x1280 1 person, 4 chairs
# image 7/15: 720x1280 1 cup, 1 chair, 3 tvs
# image 8/15: 720x1280 1 person, 3 suitcases, 1 skateboard, 1 chair, 6 tvs
# image 9/15: 720x1280 2 persons, 3 chairs, 1 potted plant, 4 tvs
# image 10/15: 720x1280 (no detections)
# image 11/15: 720x1280 2 chairs
# image 12/15: 720x1280 1 suitcase, 2 chairs, 5 tvs, 1 laptop
# image 13/15: 720x1280 1 bench
# image 14/15: 720x1280 2 persons, 6 chairs, 5 tvs
# image 15/15: 720x1280 1 person, 1 backpack, 5 chairs, 4 tvs, 1 laptop
# Speed: 47.0ms pre-process, 259.8ms inference, 1.1ms NMS per image at shape (15, 3, 384, 640)
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', '_run', 'crop', 'files', 'ims', 'n', 'names', 'pandas', 'pred', 'print', 'render', 's', 'save', 'show', 't', 'times', 'tolist', 'xywh', 'xywhn', 'xyxy', 'xyxyn']
# INFO:yolov5:Saved 15 images to runs/detect/exp13
# Saved 15 images to runs/detect/exp13
#          xmin        ymin        xmax        ymax  confidence  class    name
# 0  714.355530  195.202972  780.974670  397.673676    0.872598      0  person
# 1   32.714668  282.096649  117.219032  400.434601    0.766226     56   chair

# %%
imgs[:]
# Out:
# ['pics/rgb_15.jpeg',
#  'pics/rgb_10.jpeg',
#  'pics/rgb_12.jpeg',
#  'pics/rgb_9.jpeg',
#  'pics/rgb_14.jpeg',
#  'pics/rgb_11.jpeg',
#  'pics/rgb_8.jpeg',
#  'pics/rgb_1.jpeg',
#  'pics/rgb_4.jpeg',
#  'pics/rgb_13.jpeg',
#  'pics/rgb_2.jpeg',
#  'pics/rgb_6.jpeg',
#  'pics/rgb_7.jpeg',
#  'pics/rgb_3.jpeg',
#  'pics/rgb_5.jpeg']

# %%
#Import/setup matplotlib for results
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#See results
plt.imshow(results.ims[7])

# %% [markdown]
# Image 10=index9=rgb_15

# %%
# !unzip constructsim1(2).zip

# %%
# !wget https://gitlab.umiacs.umd.edu/vishnuds/cmsc421/-/raw/main/constructsim.zip

# %%
# !unzip constructsim.zip
# Out:
# Archive:  constructsim.zip
# replace data/1010977000000_depth.npy? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Model
my_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images
my_imgs = glob.glob('pics/*.jpeg')  # batch of images
# Inference
results = my_model(my_imgs)

# Results
results.print()
results.save()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 1  433.50  433.50   517.5  714.5    0.687988     27     tie
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# INFO:yolov5:YOLOv5 🚀 2022-10-27 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# YOLOv5 🚀 2022-10-27 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# INFO:yolov5:Fusing layers...
# Fusing layers...
# INFO:yolov5:YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# INFO:yolov5:Adding AutoShape...
# Adding AutoShape...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-a75db34d989e> in <module>
#       6 my_imgs = glob.glob('pics/*.jpeg')  # batch of images
#       7 # Inference
# ----> 8 results = my_model(my_imgs)
#       9
#      10 # Results
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward(self, ims, size, augment, profile)
#     703             # Inference
#     704             with dt[1]:
# --> 705                 y = self.model(x, augment=augment)  # forward
#     706
#     707             # Post-process
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward(self, im, augment, visualize)
#     513
#     514         if self.pt:  # PyTorch
# --> 515             y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     516         elif self.jit:  # TorchScript
#     517             y = self.model(im)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/yolo.py in forward(self, x, augment, profile, visualize)
#     207         if augment:
#     208             return self._forward_augment(x)  # augmented inference, None
# --> 209         return self._forward_once(x, profile, visualize)  # single-scale inference, train
#     210
#     211     def _forward_augment(self, x):
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/yolo.py in _forward_once(self, x, profile, visualize)
#     119             if profile:
#     120                 self._profile_one_layer(m, x, dt)
# --> 121             x = m(x)  # run
#     122             y.append(x if m.i in self.save else None)  # save output
#     123             if visualize:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward_fuse(self, x)
#      58
#      59     def forward_fuse(self, x):
# ---> 60         return self.act(self.conv(x))
#      61
#      62
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     455
#     456     def forward(self, input: Tensor) -> Tensor:
# --> 457         return self._conv_forward(input, self.weight, self.bias)
#     458
#     459 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     452                             _pair(0), self.dilation, self.groups)
#     453         return F.conv2d(input, weight, bias, self.stride,
# --> 454                         self.padding, self.dilation, self.groups)
#     455
#     456     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:
